# %%
name = "T.Gopika"
age = 19
CGPA = 8.5
placed = True

print("* Student Name:", name)
print("* Age:", age)
print("* CGPA:", CGPA)
print("* Placed:", placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
print(len(name))
# Out:
# * Student Name: T.Gopika
# * Age: 19
# * CGPA: 8.5
# * Placed: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 8
